# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (80.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install openvino-dev
# Out:
# Requirement already satisfied: openvino-dev in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (2024.6.0)
# Requirement already satisfied: defusedxml>=0.7.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (0.7.1)
# Requirement already satisfied: networkx<=3.1.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (3.1)
# Requirement already satisfied: numpy<2.0.0,>=1.16.6 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (1.26.4)
# Requirement already satisfied: openvino-telemetry>=2023.2.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (2025.1.0)
# Requirement already satisfied: packaging in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (25.0)
# Requirement already satisfied: pyyaml>=5.4.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (6.0.2)
# Requirement already satisfied: requests>=2.25.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (2.32.3)
# Requirement already satisfied: openvino==2024.6.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from openvino-dev) (2024.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests>=2.25.1->openvino-dev) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests>=2.25.1->openvino-dev) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests>=2.25.1->openvino-dev) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from requests>=2.25.1->openvino-dev) (2025.4.26)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: absl-py in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (2.2.2)
# Requirement already satisfied: numpy in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (0.0.9)
# Requirement already satisfied: h5py in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (0.15.0)
# Requirement already satisfied: ml-dtypes in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from optree->keras) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\downloads\3 in 1 (2)\3 in 1 (2)\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
dataset_path = r"D:\downloads\3 in 1 (2)\archive\archive\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\train"  # Add 'r' for raw string
print("Checking Path:", os.path.exists(dataset_path))  # Should return True

training_set = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    labels="inferred",
    label_mode="categorical",
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=42
)

print("Detected Class Names:", training_set.class_names)
# Out:
# Checking Path: True
# Found 70295 files belonging to 38 classes.
# Detected Class Names: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    r'D:\downloads\3 in 1 (2)\archive\archive\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 70295 files belonging to 38 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    r'D:\downloads\3 in 1 (2)\archive\archive\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 17572 files belonging to 38 classes.

# %%
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',input_shape=[128,128,3]))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu',input_shape=[128,128,3]))
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.25))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=1500,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dropout(0.4)) #To avoid overfitting

# %%
cnn.add(tf.keras.layers.Dense(units=38,activation='softmax'))

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 126, 126, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 63, 63, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 61, 61, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 30, 30, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 14, 14, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1500)           │     3,073,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 38)             │        57,038 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,842,762 (29.92 MB)
#  Trainable params: 7,842,762 (29.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_history = cnn.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3037s 1s/step - accuracy: 0.3678 - loss: 2.2644 - val_accuracy: 0.8204 - val_loss: 0.5733
# Epoch 2/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2971s 1s/step - accuracy: 0.8256 - loss: 0.5474 - val_accuracy: 0.9019 - val_loss: 0.2977
# Epoch 3/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2486s 1s/step - accuracy: 0.9016 - loss: 0.3061 - val_accuracy: 0.9161 - val_loss: 0.2635
# Epoch 4/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2203s 1s/step - accuracy: 0.9335 - loss: 0.2057 - val_accuracy: 0.9077 - val_loss: 0.3146
# Epoch 5/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2288s 1s/step - accuracy: 0.9476 - loss: 0.1617 - val_accuracy: 0.9444 - val_loss: 0.1783
# Epoch 6/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2202s 1s/step - accuracy: 0.9611 - loss: 0.1151 - val_accuracy: 0.9599 - val_loss: 0.1376
# Epoch 7/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2160s 980ms/step - accuracy: 0.9687 - loss: 0.0954 - val_accuracy: 0.9499 - val_loss: 0.1670
# Epoch 8/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2050s 933ms/step - accuracy: 0.9741 - loss: 0.0783 - val_accuracy: 0.9661 - val_loss: 0.1173
# Epoch 9/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2139s 972ms/step - accuracy: 0.9782 - loss: 0.0662 - val_accuracy: 0.9634 - val_loss: 0.1222
# Epoch 10/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 2131s 969ms/step - accuracy: 0.9804 - loss: 0.0595 - val_accuracy: 0.9694 - val_loss: 0.1149

# %%
#Training set Accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)
# Out:
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1960s 892ms/step - accuracy: 0.9917 - loss: 0.0248
# Training accuracy: 0.9919482469558716

# %%
#Validation set Accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 456ms/step - accuracy: 0.9702 - loss: 0.1142
# Validation accuracy: 0.9694400429725647

# %%
cnn.save('trained_plant_disease_model.keras')

# %%
training_history.history #Return Dictionary of history
# Out:
# {'accuracy': [0.5721317529678345,
#   0.8509424328804016,
#   0.9097944498062134,
#   0.9376200437545776,
#   0.9522725939750671,
#   0.9631268382072449,
#   0.9701970219612122,
#   0.9756028056144714,
#   0.9788036346435547,
#   0.9810655117034912],
#  'loss': [1.4605870246887207,
#   0.46903061866760254,
#   0.27818572521209717,
#   0.19026266038417816,
#   0.14793992042541504,
#   0.11068597435951233,
#   0.08926931768655777,
#   0.07461825758218765,
#   0.06553611904382706,
#   0.057567182928323746],
#  'val_accuracy': [0.8203960657119751,
#   0.9018893837928772,
#   0.9161165356636047,
#   0.9076940417289734,
#   0.9444001913070679,
#   0.9598793387413025,
#   0.9499203562736511,
#   0.9660823941230774,
#   0.963350772857666,
#   0.9694400429725647],
#  'val_loss': [0.573329508304596,
#   0.29767996072769165,
#   0.2634862959384918,
#   0.31459954380989075,
#   0.1783297061920166,
#   0.1376241147518158,
#   0.1669601947069168,
#   0.11734723299741745,
#   0.12223927676677704,
#   0.11486698687076569]}

# %%
#Recording History in json
import json
with open('training_hist.json','w') as f:
  json.dump(training_history.history,f)

# %%
print(training_history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
epochs = [i for i in range(1,11)]
plt.plot(epochs,training_history.history['accuracy'],color='brown',label='Training Accuracy')
plt.plot(epochs,training_history.history['val_accuracy'],color='green',label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Visualization of Accuracy Result')
plt.legend()
plt.show()

# %%
class_name = validation_set.class_names

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    r'D:\downloads\3 in 1 (2)\archive\archive\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False)
# Out:
# Found 17572 files belonging to 38 classes.

# %%
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)
# Out:
# 17572/17572 ━━━━━━━━━━━━━━━━━━━━ 348s 20ms/step

# %%
true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1)

# %%
Y_true
# Out:
# <tf.Tensor: shape=(17572,), dtype=int64, numpy=array([ 0,  0,  0, ..., 37, 37, 37], dtype=int64)>

# %%
predicted_categories
# Out:
# <tf.Tensor: shape=(17572,), dtype=int64, numpy=array([ 0,  0,  0, ..., 37, 37, 37], dtype=int64)>

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(Y_true,predicted_categories)

# %%
print(classification_report(Y_true,predicted_categories,target_names=class_name))
# Out:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.95      0.96      0.95       504
#                                  Apple___Black_rot       0.95      0.99      0.97       497
#                           Apple___Cedar_apple_rust       0.98      0.99      0.98       440
#                                    Apple___healthy       0.99      0.92      0.95       502
#                                Blueberry___healthy       0.98      0.96      0.97       454
#           Cherry_(including_sour)___Powdery_mildew       0.93      1.00      0.96       421
#                  Cherry_(including_sour)___healthy       1.00      0.98      0.99       456
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.92      0.94      0.93       410
#                        Corn_(maize)___Common_rust_       1.00      0.99      0.99       477
#                Corn_(maize)___Northern_Leaf_Blight       0.95      0.95      0.95       477
#                             Corn_(maize)___healthy       0.99      1.00      1.00       465
#                                  Grape___Black_rot       0.97      1.00      0.98       472
#                       Grape___Esca_(Black_Measles)       1.00      0.98      0.99       480
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      0.99      1.00       430
#                                    Grape___healthy       0.99      0.99      0.99       423
#           Orange___Haunglongbing_(Citrus_greening)       0.99      0.99      0.99       503
#                             Peach___Bacterial_spot       0.93      0.98      0.95       459
#                                    Peach___healthy       0.97      0.98      0.97       432
#                      Pepper,_bell___Bacterial_spot       0.95      0.99      0.97       478
#                             Pepper,_bell___healthy       0.93      0.98      0.95       497
#                              Potato___Early_blight       0.99      0.99      0.99       485
#                               Potato___Late_blight       0.97      0.97      0.97       485
#                                   Potato___healthy       0.98      0.99      0.98       456
#                                Raspberry___healthy       1.00      0.98      0.99       445
#                                  Soybean___healthy       0.99      0.94      0.97       505
#                            Squash___Powdery_mildew       0.98      1.00      0.99       434
#                           Strawberry___Leaf_scorch       0.99      0.98      0.98       444
#                               Strawberry___healthy       0.98      0.99      0.99       456
#                            Tomato___Bacterial_spot       0.99      0.93      0.96       425
#                              Tomato___Early_blight       0.95      0.91      0.93       480
#                               Tomato___Late_blight       0.96      0.92      0.94       463
#                                 Tomato___Leaf_Mold       0.98      0.97      0.98       470
#                        Tomato___Septoria_leaf_spot       0.97      0.88      0.92       436
#      Tomato___Spider_mites Two-spotted_spider_mite       0.97      0.92      0.95       435
#                               Tomato___Target_Spot       0.92      0.92      0.92       457
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.98      0.99      0.99       490
#                       Tomato___Tomato_mosaic_virus       0.92      1.00      0.96       448
#                                   Tomato___healthy       0.98      0.99      0.99       481
#
#                                           accuracy                           0.97     17572
#                                          macro avg       0.97      0.97      0.97     17572
#                                       weighted avg       0.97      0.97      0.97     17572

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(cm,annot=True,annot_kws={"size": 10}, cmap='tab10')

plt.xlabel('Predicted Class',fontsize = 30)
plt.ylabel('Actual Class',fontsize = 40)
plt.title('Plant Disease Prediction Confusion Matrix',fontsize = 25)
plt.show()
